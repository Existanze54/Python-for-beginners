# %% [markdown]
# # Задача 1
#
# Вам дана строка: Я сегодня пришел на зачёт и сделал ВСЕ задания. Верните строку, в которой все символы будут отсортированы в алфавитном порядке

# %%
# Место для решения

# %% [markdown]
# # Задача 2
#
# Вам даны 2 списка. Задача расшифровать едложение. Задача найти такие символы, которые есть в обоих списках, получить их в том порядке, в котором они должны следовать и перевести их из кодировки ASCII в буквенную кодировку (для этого используйте функцию chr)
#
# [5, 5, 89, 1, 1, 13, 6, 10, 9, 111, 10, 117, 13, 6, 11, 8, 2, 6, 6, 32, 114, 6, 101, 10, 3, 0, 10, 13, 0, 6, 7, 1, 4, 1, 2, 3, 1, 12, 1, 10, 6, 13, 5, 7, 11, 97, 12, 12, 5, 8, 108, 3, 1, 5, 10, 9, 6, 121, 10, 6, 13, 32, 1, 2, 6, 100, 111, 32, 4, 3, 0, 105, 2, 13, 116, 63]
#
#
# [20, 21, 15, 18, 19, 89, 27, 27, 23, 111, 18, 16, 24, 18, 18, 23, 21, 28, 23, 24, 19, 16, 15, 18, 117, 24, 24, 23, 32, 28, 114, 22, 16, 28, 101, 22, 97, 19, 108, 121, 23, 23, 24, 20, 32, 20, 100, 25, 111, 26, 16, 17, 32, 105, 116, 63]

# %%
# Место для решения

# %% [markdown]
# # Задача 3
#
# - напишите функцию, которая принимает строку. В строке могут находиться символы 'ALPAKWOMBT'
# - внутри этой функции создайте структуру данных которая бы хранила эти символы и присудите первым пяти из них какое-то целое число от 1 до 5, а вторым 5 какое-то отрицательное число, от -1 до -5
# - сгенерируйте случайную строку из этих символов длинной 30 и посчитайте сумму всех чисел в строке. Какие символы победили (на основании суммы чисел. Если отрицательная сумма, победил WOMBT; если сумма положительная, победил ALPAK)?

# %%
# Место для решения

# %% [markdown]
# # Задача 4
#
# Напишите функцию, которая принимает и сортирует буквы в строке в зависимости от регистра. Также данная функция должна посчитать, сколько гласных и сколько согласных букв в передаваемой ей строке

# %%
# Место для решения

# %% [markdown]
# # Задача 5
# Вам дана база данных *database.sqlite* (файл расположен в одной директории с ноутбуком с этим заданием). База данных состоит из трёх таблиц: chip_experiments (таблица с экспериментами), cells (таблица, описывающая клеточные линии) и uniprot (таблица с регуляторными белками). Напишите запрос, позволяющий ответить на вопрос: сколько белков-регуляторов было исследовано в экспериментах, поставленных на клеточных линиях, в названии которых есть слово *cancer*.

# %% [markdown]
# ![GTRD_part_db_structure.svg](attachment:GTRD_part_db_structure.svg)

# %%
# Место для решения

# %% [markdown]
# # Задача 6
# Напишите bash-скрипт, который делает следующее:
# 1. Создаёт директорию results
# 2. Скачивает файл с аннотацией генома [данио-рерио](https://ftp.ncbi.nlm.nih.gov/refseq/D_rerio/annotation_releases/current/GCF_000002035.6_GRCz11/GCF_000002035.6_GRCz11_genomic.gff.gz)
# 3. Распаковывает архив
# 4. Создаёт новый файл в директории results, содержаший в себе 1,3 и 9 столбец распакованного файла
# 5. Выводит количество генов (2 колонка нового файла == "gene") в хромосоме NC_007112.7 (1 колонка)
